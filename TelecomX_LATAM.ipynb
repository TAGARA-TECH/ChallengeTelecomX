# %% [markdown]
# <a href="https://colab.research.google.com/github/TAGARA-TECH/ChallengeTelecomX/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
import requests

# URL del archivo JSON crudo
url = 'https://raw.githubusercontent.com/TAGARA-TECH/ChallengeTelecomX/main/TelecomX_Data.json'

# Obtener los datos desde la "API"
response = requests.get(url)
data_json = response.json()

# Convertir a DataFrame
df = pd.DataFrame(data_json)

# Mostrar las primeras filas
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
# Vista general del DataFrame
print("Dimensiones del dataset:", df.shape)

# Columnas y tipos de datos
df.info()

# Tipos de datos por separado
print("\nTipos de datos:")
print(df.dtypes)

# Primeras filas para exploración visual
df.head()
# Out:
# Dimensiones del dataset: (7267, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB
#
# Tipos de datos:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
# Estadísticas de variables numéricas
df.describe()

# Ver valores únicos por columna (para identificar categóricas)

for col in df.columns:
    try:
        unique_vals = df[col].nunique()
        print(f"{col}: {unique_vals} valores únicos")
    except TypeError as e:
        print(f"⚠️ Error en columna '{col}': {e}")
        print(f"🔍 Primeros 2 valores no nulos en '{col}':")
        print(df[col].dropna().head(2).tolist())
# Out:
# customerID: 7267 valores únicos
# Churn: 3 valores únicos
# ⚠️ Error en columna 'customer': unhashable type: 'dict'
# 🔍 Primeros 2 valores no nulos en 'customer':
# [{'gender': 'Female', 'SeniorCitizen': 0, 'Partner': 'Yes', 'Dependents': 'Yes', 'tenure': 9}, {'gender': 'Male', 'SeniorCitizen': 0, 'Partner': 'No', 'Dependents': 'No', 'tenure': 9}]
# ⚠️ Error en columna 'phone': unhashable type: 'dict'
# 🔍 Primeros 2 valores no nulos en 'phone':
# [{'PhoneService': 'Yes', 'MultipleLines': 'No'}, {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}]
# ⚠️ Error en columna 'internet': unhashable type: 'dict'
# 🔍 Primeros 2 valores no nulos en 'internet':
# [{'InternetService': 'DSL', 'OnlineSecurity': 'No', 'OnlineBackup': 'Yes', 'DeviceProtection': 'No', 'TechSupport': 'Yes', 'StreamingTV': 'Yes', 'StreamingMovies': 'No'}, {'InternetService': 'DSL', 'OnlineSecurity': 'No', 'OnlineBackup': 'No', 'DeviceProtection': 'No', 'TechSupport': 'No', 'StreamingTV': 'No', 'StreamingMovies': 'Yes'}]
# ⚠️ Error en columna 'account': unhashable type: 'dict'
# 🔍 Primeros 2 valores no nulos en 'account':
# [{'Contract': 'One year', 'PaperlessBilling': 'Yes', 'PaymentMethod': 'Mailed check', 'Charges': {'Monthly': 65.6, 'Total': '593.3'}}, {'Contract': 'Month-to-month', 'PaperlessBilling': 'No', 'PaymentMethod': 'Mailed check', 'Charges': {'Monthly': 59.9, 'Total': '542.4'}}]

# %% [markdown]
#  el dataset tiene columnas anidadas, es decir, varias columnas contienen diccionarios dentro de cada fila. Para poder analizarlas correctamente en pandas, hay que "aplanarlas" (flatten), es decir, convertir esas claves internas en columnas separadas.

# %%
# Expandir la columna 'customer'
customer_df = df['customer'].apply(pd.Series)
df = df.drop('customer', axis=1).join(customer_df)

# Expandir la columna 'phone'
phone_df = df['phone'].apply(pd.Series)
df = df.drop('phone', axis=1).join(phone_df)

# Expandir la columna 'internet'
internet_df = df['internet'].apply(pd.Series)
df = df.drop('internet', axis=1).join(internet_df)

# Expandir la columna 'account'
account_df = df['account'].apply(pd.Series)

# Extraer también los valores anidados en 'Charges'
charges_df = account_df['Charges'].apply(pd.Series)
account_df = account_df.drop('Charges', axis=1).join(charges_df)

# Unir todo al DataFrame original
df = df.drop('account', axis=1).join(account_df)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   customer_id       0 non-null      object
#  3   gender            7267 non-null   object
#  4   SeniorCitizen     7267 non-null   int64
#  5   Partner           7267 non-null   object
#  6   Dependents        7267 non-null   object
#  7   tenure            7267 non-null   int64
#  8   PhoneService      7267 non-null   object
#  9   MultipleLines     7267 non-null   object
#  10  InternetService   7267 non-null   object
#  11  OnlineSecurity    7267 non-null   object
#  12  OnlineBackup      7267 non-null   object
#  13  DeviceProtection  7267 non-null   object
#  14  TechSupport       7267 non-null   object
#  15  StreamingTV       7267 non-null   object
#  16  StreamingMovies   7267 non-null   object
#  17  Contract          7267 non-null   object
#  18  PaperlessBilling  7267 non-null   object
#  19  PaymentMethod     7267 non-null   object
#  20  Monthly           7267 non-null   float64
#  21  Total             7267 non-null   object
# dtypes: float64(1), int64(2), object(19)
# memory usage: 1.2+ MB
#    customerID Churn customer_id  gender  SeniorCitizen Partner Dependents  \
# 0  0002-ORFBO    No        None  Female              0     Yes        Yes
# 1  0003-MKNFE    No        None    Male              0      No         No
# 2  0004-TLHLJ   Yes        None    Male              0      No         No
# 3  0011-IGKFF   Yes        None    Male              1     Yes         No
# 4  0013-EXCHZ   Yes        None  Female              1     Yes         No
#
#    tenure PhoneService MultipleLines  ... OnlineBackup DeviceProtection  \
# 0       9          Yes            No  ...          Yes               No
# 1       9          Yes           Yes  ...           No               No
# 2       4          Yes            No  ...           No              Yes
# 3      13          Yes            No  ...          Yes              Yes
# 4       3          Yes            No  ...           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes         Yes              No        One year              Yes
# 1          No          No             Yes  Month-to-month               No
# 2          No          No              No  Month-to-month              Yes
# 3          No         Yes             Yes  Month-to-month              Yes
# 4         Yes         Yes              No  Month-to-month              Yes
#
#       PaymentMethod Monthly    Total
# 0      Mailed check    65.6    593.3
# 1      Mailed check    59.9    542.4
# 2  Electronic check    73.9   280.85
# 3  Electronic check    98.0  1237.85
# 4      Mailed check    83.9    267.4
#
# [5 rows x 22 columns]

# %% [markdown]
#  Resumen del estado actual
# 🔹 Todas las columnas anidadas ya están desglosadas correctamente.
#
# 🔹 customer_id está completamente vacío (0 non-null), por lo tanto podés eliminarla.
#
# 🔹 La columna Total está como object, aunque debería ser numérica (float), probablemente porque hay algunos valores mal formateados (por ejemplo, strings vacíos, espacios o caracteres no numéricos).
#
# Pasos a seguir:
# Eliminar customer_id.
#
# Convertir Total a numérico (y ver qué errores aparecen si los hay).
#
# Verificar si hay valores nulos tras esa conversión.

# %%
# 1. Eliminar columna vacía
df.drop(columns=['customer_id'], inplace=True)

# 2. Convertir 'Total' a numérico, forzando errores a NaN si hay problemas
df['Total'] = pd.to_numeric(df['Total'], errors='coerce')

# 3. Verificar si hubo valores nulos generados en 'Total'
print(f"Valores nulos en 'Total': {df['Total'].isna().sum()}")
# Out:
# Valores nulos en 'Total': 11

# %%
df.describe(include='all')
# Out:
#         customerID Churn gender  SeniorCitizen Partner Dependents  \
# count         7267  7267   7267    7267.000000    7267       7267
# unique        7267     3      2            NaN       2          2
# top     9995-HOTOH    No   Male            NaN      No         No
# freq             1  5174   3675            NaN    3749       5086
# mean           NaN   NaN    NaN       0.162653     NaN        NaN
# std            NaN   NaN    NaN       0.369074     NaN        NaN
# min            NaN   NaN    NaN       0.000000     NaN        NaN
# 25%            NaN   NaN    NaN       0.000000     NaN        NaN
# 50%            NaN   NaN    NaN       0.000000     NaN        NaN
# 75%            NaN   NaN    NaN       0.000000     NaN        NaN
# max            NaN   NaN    NaN       1.000000     NaN        NaN
#
#              tenure PhoneService MultipleLines InternetService  ...  \
# count   7267.000000         7267          7267            7267  ...
# unique          NaN            2             3               3  ...
# top             NaN          Yes            No     Fiber optic  ...
# freq            NaN         6560          3495            3198  ...
# mean      32.346498          NaN           NaN             NaN  ...
# std       24.571773          NaN           NaN             NaN  ...
# min        0.000000          NaN           NaN             NaN  ...
# 25%        9.000000          NaN           NaN             NaN  ...
# 50%       29.000000          NaN           NaN             NaN  ...
# 75%       55.000000          NaN           NaN             NaN  ...
# max       72.000000          NaN           NaN             NaN  ...
#
#        OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# count          7267             7267        7267        7267            7267
# unique            3                3           3           3               3
# top              No               No          No          No              No
# freq           3182             3195        3582        2896            2870
# mean            NaN              NaN         NaN         NaN             NaN
# std             NaN              NaN         NaN         NaN             NaN
# min             NaN              NaN         NaN         NaN             NaN
# 25%             NaN              NaN         NaN         NaN             NaN
# 50%             NaN              NaN         NaN         NaN             NaN
# 75%             NaN              NaN         NaN         NaN             NaN
# max             NaN              NaN         NaN         NaN             NaN
#
#               Contract PaperlessBilling     PaymentMethod      Monthly  \
# count             7267             7267              7267  7267.000000
# unique               3                2                 4          NaN
# top     Month-to-month              Yes  Electronic check          NaN
# freq              4005             4311              2445          NaN
# mean               NaN              NaN               NaN    64.720098
# std                NaN              NaN               NaN    30.129572
# min                NaN              NaN               NaN    18.250000
# 25%                NaN              NaN               NaN    35.425000
# 50%                NaN              NaN               NaN    70.300000
# 75%                NaN              NaN               NaN    89.875000
# max                NaN              NaN               NaN   118.750000
#
#               Total
# count   7256.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean    2280.634213
# std     2268.632997
# min       18.800000
# 25%      400.225000
# 50%     1391.000000
# 75%     3785.300000
# max     8684.800000
#
# [11 rows x 21 columns]

# %%
df['Churn'].value_counts(normalize=True)
# Out:
# Churn
# No     0.711986
# Yes    0.257190
#        0.030824
# Name: proportion, dtype: float64

# %%
df.isna().sum()
# Out:
# customerID           0
# Churn                0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# Monthly              0
# Total               11
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x='Churn')
plt.title("Distribución de Churn")
plt.show()

# %% [markdown]
# ## **Verificar si hay problemas en los datos que puedan afectar el análisis**
# Esta etapa consiste en detectar y limpiar posibles problemas como:

# %%
#1. Valores ausentes (NaN o None)
df.isna().sum().sort_values(ascending=False)
# Out:
# Total               11
# Churn                0
# gender               0
# SeniorCitizen        0
# customerID           0
# Partner              0
# Dependents           0
# PhoneService         0
# tenure               0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# MultipleLines        0
# DeviceProtection     0
# TechSupport          0
# StreamingMovies      0
# StreamingTV          0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# Monthly              0
# dtype: int64

# %%
#porcentaje de valores faltante
(df.isna().sum() / len(df)).sort_values(ascending=False)
# Out:
# Total               0.001514
# Churn               0.000000
# gender              0.000000
# SeniorCitizen       0.000000
# customerID          0.000000
# Partner             0.000000
# Dependents          0.000000
# PhoneService        0.000000
# tenure              0.000000
# InternetService     0.000000
# OnlineSecurity      0.000000
# OnlineBackup        0.000000
# MultipleLines       0.000000
# DeviceProtection    0.000000
# TechSupport         0.000000
# StreamingMovies     0.000000
# StreamingTV         0.000000
# Contract            0.000000
# PaperlessBilling    0.000000
# PaymentMethod       0.000000
# Monthly             0.000000
# dtype: float64

# %%
#2. Valores duplicados
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Si hay duplicados, podés eliminarlos con:
df = df.drop_duplicates()

# %%
#3. Errores de formato
for col in df.select_dtypes(include='object'):
    df[col] = df[col].str.strip()
#Si hay columnas con fechas (parece que no en este dataset), ahí se usaría .dt.normalize() como menciona el tip.

# %%
#4. Inconsistencias en categorías
for col in df.select_dtypes(include='object'):
    print(f"{col}: {df[col].unique()}")
# Out:
# customerID: ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# Churn: ['No' 'Yes' '']
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['Yes' 'No']
# PhoneService: ['Yes' 'No']
# MultipleLines: ['No' 'Yes' 'No phone service']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['Yes' 'No' 'No internet service']
# StreamingTV: ['Yes' 'No' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['One year' 'Month-to-month' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']

# %%
#Churn: ['No' 'Yes' '']
df['Churn'] = df['Churn'].replace('', np.nan)

# %%
#MultipleLines: ['No' 'Yes' 'No phone service']
df['MultipleLines'] = df['MultipleLines'].replace('No phone service', 'No')

# %%
 #Columnas con 'No internet service':
 cols_internet = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                 'TechSupport', 'StreamingTV', 'StreamingMovies']

for col in cols_internet:
    df[col] = df[col].replace('No internet service', 'No')
#Esta opción es muy común en análisis predictivo.

# %% [markdown]
#  Todo lo demás:
# 'gender', 'Partner', 'Dependents', 'PhoneService', 'Contract', 'PaperlessBilling', 'PaymentMethod' → No tienen inconsistencias, ¡bien!

# %%
# mini script para que limpies todo esto junto (de forma controlada):
import numpy as np

# Reemplazar valores vacíos en Churn
df['Churn'] = df['Churn'].replace('', np.nan)

# Reemplazar 'No phone service' en MultipleLines
df['MultipleLines'] = df['MultipleLines'].replace('No phone service', 'No')

# Reemplazar 'No internet service' en varias columnas
cols_internet = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                 'TechSupport', 'StreamingTV', 'StreamingMovies']
for col in cols_internet:
    df[col] = df[col].replace('No internet service', 'No')

# %%
#4. Inconsistencias en categorías
for col in df.select_dtypes(include='object'):
    print(f"{col}: {df[col].unique()}")
# Out:
# customerID: ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# Churn: ['No' 'Yes' nan]
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['Yes' 'No']
# PhoneService: ['Yes' 'No']
# MultipleLines: ['No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes']
# OnlineBackup: ['Yes' 'No']
# DeviceProtection: ['No' 'Yes']
# TechSupport: ['Yes' 'No']
# StreamingTV: ['Yes' 'No']
# StreamingMovies: ['No' 'Yes']
# Contract: ['One year' 'Month-to-month' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']

# %% [markdown]
# ## Analisis de Gemini

# %%
# Verificar cuántas filas tienen Churn vacío
print(df[df['Churn'] == ''].shape[0])

# Opción 1: Eliminar filas con Churn vacío (si son pocas y no cruciales)
df = df[df['Churn'] != ''].copy() # Usar .copy() para evitar SettingWithCopyWarning

# Opción 2: Reemplazar con NaN y luego decidir cómo imputar si fuera necesario para otras variables
# df['Churn'] = df['Churn'].replace('', np.nan)
# Out:
# 0

# %% [markdown]
# #🔧 Transformación

# %% [markdown]
# ##Fase de Transformación: Desanidando Columnas
# El siguiente paso es crucial: vamos a desanidar las columnas que contienen diccionarios para que toda la información quede accesible y lista para el análisis. Como vimos, customer, phone, internet y account son las columnas que necesitamos expandir.

# %%
import pandas as pd
import requests

# Re-cargamos los datos para asegurarnos de tener el estado inicial (o el último que hayas guardado)
url = 'https://raw.githubusercontent.com/TAGARA-TECH/ChallengeTelecomX/main/TelecomX_Data.json'
response = requests.get(url)
data_json = response.json()
df = pd.DataFrame(data_json)

print("DataFrame original (primeras 3 filas):")
print(df.head(3))
print("\n---")

# --- Desanidando la columna 'customer' ---
# pd.json_normalize es ideal si tuvieras un JSON más complejo o si estuvieras cargando directo desde un JSON con estructuras anidadas.
# Para este caso, .apply(pd.Series) funciona bien para expandir una columna de diccionarios en un DataFrame.
df_customer_expanded = df['customer'].apply(pd.Series)
print("\nColumnas expandidas de 'customer' (primeras 3 filas):")
print(df_customer_expanded.head(3))
print("\n---")


# --- Desanidando la columna 'phone' ---
df_phone_expanded = df['phone'].apply(pd.Series)
print("\nColumnas expandidas de 'phone' (primeras 3 filas):")
print(df_phone_expanded.head(3))
print("\n---")


# --- Desanidando la columna 'internet' ---
df_internet_expanded = df['internet'].apply(pd.Series)
print("\nColumnas expandidas de 'internet' (primeras 3 filas):")
print(df_internet_expanded.head(3))
print("\n---")


# --- Desanidando la columna 'account' ---
df_account_expanded = df['account'].apply(pd.Series)
print("\nColumnas expandidas de 'account' (primeras 3 filas):")
print(df_account_expanded.head(3))
print("\n---")


# --- Combinando todo en un solo DataFrame ---
# 1. Eliminamos las columnas originales que contenían los diccionarios.
df = df.drop(columns=['customer', 'phone', 'internet', 'account'])

# 2. Concatenamos los DataFrames expandidos al DataFrame principal.
#    'axis=1' asegura que se concatenen como nuevas columnas.
df = pd.concat([df, df_customer_expanded, df_phone_expanded, df_internet_expanded, df_account_expanded], axis=1)

print("\nDataFrame después de desanidar (primeras 5 filas):")
print(df.head())
print("\n---")

# Verificamos la nueva estructura y tipos de datos
print("\nDimensiones del DataFrame después de desanidar:", df.shape)
print("\nInformación del DataFrame después de desanidar:")
df.info()
# Out:
# DataFrame original (primeras 3 filas):
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
#
# ---
#
# Columnas expandidas de 'customer' (primeras 3 filas):
#    gender  SeniorCitizen Partner Dependents  tenure
# 0  Female              0     Yes        Yes       9
# 1    Male              0      No         No       9
# 2    Male              0      No         No       4
#
# ---
#
# Columnas expandidas de 'phone' (primeras 3 filas):
#   PhoneService MultipleLines
# 0          Yes            No
# 1          Yes           Yes
# 2          Yes            No
#
# ---
#
# Columnas expandidas de 'internet' (primeras 3 filas):
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL             No          Yes               No         Yes
# 1             DSL             No           No               No          No
# 2     Fiber optic             No           No              Yes          No
#
#   StreamingTV StreamingMovies
# 0         Yes              No
# 1          No             Yes
# 2          No              No
#
# ---
#
# Columnas expandidas de 'account' (primeras 3 filas):
#          Contract PaperlessBilling     PaymentMethod  \
# 0        One year              Yes      Mailed check
# 1  Month-to-month               No      Mailed check
# 2  Month-to-month              Yes  Electronic check
#
#                                 Charges
# 0   {'Monthly': 65.6, 'Total': '593.3'}
# 1   {'Monthly': 59.9, 'Total': '542.4'}
# 2  {'Monthly': 73.9, 'Total': '280.85'}
#
# ---
#
# DataFrame después de desanidar (primeras 5 filas):
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          Yes            No             DSL             No          Yes
# 1          Yes           Yes             DSL             No           No
# 2          Yes            No     Fiber optic             No           No
# 3          Yes            No     Fiber optic             No          Yes
# 4          Yes            No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
# 3              Yes          No         Yes             Yes  Month-to-month
# 4               No         Yes         Yes              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod                                Charges
# 0              Yes      Mailed check    {'Monthly': 65.6, 'Total': '593.3'}
# 1               No      Mailed check    {'Monthly': 59.9, 'Total': '542.4'}
# 2              Yes  Electronic check   {'Monthly': 73.9, 'Total': '280.85'}
# 3              Yes  Electronic check  {'Monthly': 98.0, 'Total': '1237.85'}
# 4              Yes      Mailed check    {'Monthly': 83.9, 'Total': '267.4'}
#
# ---
#
# Dimensiones del DataFrame después de desanidar: (7267, 20)
#
# Información del DataFrame después de desanidar:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges           7267 non-null   object
# dtypes: int64(2), object(18)
# memory usage: 1.1+ MB

# %%
print(df.head())
print(df.info())
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          Yes            No             DSL             No          Yes
# 1          Yes           Yes             DSL             No           No
# 2          Yes            No     Fiber optic             No           No
# 3          Yes            No     Fiber optic             No          Yes
# 4          Yes            No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
# 3              Yes          No         Yes             Yes  Month-to-month
# 4               No         Yes         Yes              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod                                Charges
# 0              Yes      Mailed check    {'Monthly': 65.6, 'Total': '593.3'}
# 1               No      Mailed check    {'Monthly': 59.9, 'Total': '542.4'}
# 2              Yes  Electronic check   {'Monthly': 73.9, 'Total': '280.85'}
# 3              Yes  Electronic check  {'Monthly': 98.0, 'Total': '1237.85'}
# 4              Yes      Mailed check    {'Monthly': 83.9, 'Total': '267.4'}
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges           7267 non-null   object
# dtypes: int64(2), object(18)
# memory usage: 1.1+ MB
# None

# %% [markdown]
# ### siguientes pasos:
#
# Desanidar la columna Charges en Monthly y Total.
# Convertir Monthly y Total a tipos numéricos y manejar los posibles valores no numéricos.
# Tratar la columna Churn: reemplazar los valores vacíos con NA y eliminar las filas correspondientes.
# Convertir las columnas categóricas al tipo category para optimizar el rendimiento y asegurar un manejo adecuado en el análisis.

# %%
import pandas as pd
import requests
import numpy as np # Necesario para pd.NA y fillna(0)

# Re-cargamos los datos para asegurarnos de tener el estado inicial (o el último que hayas guardado)
url = 'https://raw.githubusercontent.com/TAGARA-TECH/ChallengeTelecomX/main/TelecomX_Data.json'
response = requests.get(url)
data_json = response.json()
df = pd.DataFrame(data_json)

print("DataFrame original (primeras 3 filas):")
print(df.head(3))
print("\n---")

# --- Desanidando las columnas ---
df_customer_expanded = df['customer'].apply(pd.Series)
df_phone_expanded = df['phone'].apply(pd.Series)
df_internet_expanded = df['internet'].apply(pd.Series)
df_account_expanded = df['account'].apply(pd.Series)

# --- Desanidando la columna 'Charges' dentro de 'account' ---
# Verificamos si la columna 'Charges' existe en df_account_expanded antes de intentar desanidar
if 'Charges' in df_account_expanded.columns:
    df_charges_expanded = df_account_expanded['Charges'].apply(pd.Series)
    df_account_expanded = df_account_expanded.drop(columns=['Charges']) # Eliminar 'Charges' del df_account_expanded
    print("Columna 'Charges' desanidada correctamente.")
else:
    # Si 'Charges' no está en df_account_expanded (quizás ya se desanidó o el JSON cambió),
    # creamos un DataFrame vacío para evitar errores de concatenación más adelante.
    df_charges_expanded = pd.DataFrame()
    print("Advertencia: La columna 'Charges' no se encontró en df_account_expanded para desanidar.")


# --- Combinando todo en un solo DataFrame ---
# 1. Eliminamos las columnas originales que contenían los diccionarios.
cols_to_drop_original = ['customer', 'phone', 'internet', 'account']
df = df.drop(columns=[col for col in cols_to_drop_original if col in df.columns]) # Eliminar solo si existen

# 2. Concatenamos los DataFrames expandidos al DataFrame principal.
#    Aseguramos que los DataFrames expandidos no estén vacíos antes de concatenar.
dataframes_to_concat = [df]
if not df_customer_expanded.empty:
    dataframes_to_concat.append(df_customer_expanded)
if not df_phone_expanded.empty:
    dataframes_to_concat.append(df_phone_expanded)
if not df_internet_expanded.empty:
    dataframes_to_concat.append(df_internet_expanded)
if not df_account_expanded.empty:
    dataframes_to_concat.append(df_account_expanded)
if not df_charges_expanded.empty:
     dataframes_to_concat.append(df_charges_expanded)

df = pd.concat(dataframes_to_concat, axis=1)


print("\nDataFrame después de desanidar (primeras 5 filas):")
print(df.head())
print("\n---")

# --- Eliminar la columna 'customerID' ya que no es necesaria para el análisis ---
# Ahora que customerID ha sido expandida, la eliminamos.
if 'customerID' in df.columns:
    df.drop(columns=['customerID'], inplace=True)
    print("\nColumna 'customerID' eliminada.")
else:
    print("\nLa columna 'customerID' no se encontró (ya había sido eliminada o no se creó).")


# --- 2. Convertir 'Monthly' y 'Total' a tipos numéricos y manejar NaNs ---
# La columna 'Total' (y a veces 'Monthly' si el cliente no ha generado cargos aún) puede tener valores no numéricos (e.g., espacios en blanco)
# 'errors='coerce'' convertirá cualquier valor que no pueda ser numérico a NaN.
# Añadir verificación antes de convertir para asegurar que las columnas existen
if 'Total' in df.columns:
    df['Total'] = pd.to_numeric(df['Total'], errors='coerce')
    # Rellenar los valores NaN (introducidos por 'coerce') con 0.
    df['Total'] = df['Total'].fillna(0)
    print(f"Valores nulos en 'Total' después de rellenar con 0: {df['Total'].isna().sum()}")
else:
     print("La columna 'Total' no se encontró para convertir a numérico.")


if 'Monthly' in df.columns:
    df['Monthly'] = pd.to_numeric(df['Monthly'], errors='coerce')
    # Rellenar los valores NaN (introducidos por 'coerce') con 0.
    df['Monthly'] = df['Monthly'].fillna(0)
    print(f"Valores nulos en 'Monthly' después de rellenar con 0: {df['Monthly'].isna().sum()}")
else:
    print("La columna 'Monthly' no se encontró para convertir a numérico.")


# --- 3. Tratamiento de valores en blanco en la columna 'Churn' ---
# Identificamos los valores únicos en 'Churn' para confirmar la presencia de la cadena vacía.
if 'Churn' in df.columns:
    print("Valores únicos en 'Churn' ANTES de la limpieza:", df['Churn'].unique())

    # Reemplazamos la cadena vacía '' por pd.NA (un marcador de valor faltante de Pandas).
    df['Churn'] = df['Churn'].replace('', pd.NA)

    # Eliminamos las filas donde 'Churn' es NA. Esto es crucial para nuestra variable objetivo.
    df.dropna(subset=['Churn'], inplace=True)

    print("Valores únicos en 'Churn' DESPUÉS de la limpieza:", df['Churn'].unique())
    print(f"Número de filas después de eliminar NAs en 'Churn': {len(df)}")
else:
    print("La columna 'Churn' no se encontró para limpieza.")

print("\n---")

# --- 4. Conversión de tipos de datos ---
# Creamos una lista de columnas que identificamos como categóricas.
# customerID es un identificador, no una característica para modelar directamente, así que la excluimos de la conversión a 'category'.
# Asegúrate de que las columnas existan antes de intentar convertirlas.
categorical_cols = [
    'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
    'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
    'PaperlessBilling', 'PaymentMethod', 'Churn' # 'Churn' también es categórica (Yes/No)
]

# Convertimos cada columna en la lista a tipo 'category'.
for col in categorical_cols:
    if col in df.columns: # Verificamos que la columna exista para evitar errores
        df[col] = df[col].astype('category')
    else:
        print(f"Advertencia: La columna '{col}' no se encontró para convertir a tipo 'category'.")


# Verificamos que las columnas numéricas estén en el tipo correcto (SeniorCitizen y tenure ya eran int64, Monthly y Total ya son float64)
# No es necesario hacer una conversión explícita si ya están en el tipo correcto.

print("\nDimensiones finales del DataFrame después de todas las transformaciones:", df.shape)
print("\nInformación final del DataFrame:")
df.info()

if 'Churn' in df.columns:
    print("\nConteo de valores de Churn (final):")
    print(df['Churn'].value_counts())
# Out:
# DataFrame original (primeras 3 filas):
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
#
# ---
# Columna 'Charges' desanidada correctamente.
#
# DataFrame después de desanidar (primeras 5 filas):
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService  ... OnlineBackup  \
# 0          Yes            No             DSL  ...          Yes
# 1          Yes           Yes             DSL  ...           No
# 2          Yes            No     Fiber optic  ...           No
# 3          Yes            No     Fiber optic  ...          Yes
# 4          Yes            No     Fiber optic  ...           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
# 3              Yes          No         Yes             Yes  Month-to-month
# 4               No         Yes         Yes              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod Monthly    Total
# 0              Yes      Mailed check    65.6    593.3
# 1               No      Mailed check    59.9    542.4
# 2              Yes  Electronic check    73.9   280.85
# 3              Yes  Electronic check    98.0  1237.85
# 4              Yes      Mailed check    83.9    267.4
#
# [5 rows x 21 columns]
#
# ---
#
# Columna 'customerID' eliminada.
# Valores nulos en 'Total' después de rellenar con 0: 0
# Valores nulos en 'Monthly' después de rellenar con 0: 0
# Valores únicos en 'Churn' ANTES de la limpieza: ['No' 'Yes' '']
# Valores únicos en 'Churn' DESPUÉS de la limpieza: ['No' 'Yes']
# Número de filas después de eliminar NAs en 'Churn': 7043
#
# ---
#
# Dimensiones finales del DataFrame después de todas las transformaciones: (7043, 20)
#
# Información final del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Churn             7043 non-null   category
#  1   gender            7043 non-null   category
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   category
#  4   Dependents        7043 non-null   category
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   category
#  7   MultipleLines     7043 non-null   category
#  8   InternetService   7043 non-null   category
#  9   OnlineSecurity    7043 non-null   category
#  10  OnlineBackup      7043 non-null   category
#  11  DeviceProtection  7043 non-null   category
#  12  TechSupport       7043 non-null   category
#  13  StreamingTV       7043 non-null   category
#  14  StreamingMovies   7043 non-null   category
#  15  Contract          7043 non-null   category
#  16  PaperlessBilling  7043 non-null   category
#  17  PaymentMethod     7043 non-null   category
#  18  Monthly           7043 non-null   float64
#  19  Total             7043 non-null   float64
# dtypes: category(16), float64(2), int64(2)
# memory usage: 387.2 KB
#
# Conteo de valores de Churn (final):
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# ###  ¡Ahora pasamos a la fase de Análisis Exploratorio de Datos (EDA)!
# El EDA es donde empezamos a descubrir patrones, relaciones y anomalías en los datos. Esto nos ayudará a entender qué factores podrían estar influyendo en el churn de los clientes de Telecom X.
#
# Podemos abordar el EDA de varias maneras. Te sugiero que comencemos con los siguientes pasos:
#
# Análisis de la distribución de la variable objetivo (Churn): Ver la proporción de clientes que se fueron (Yes) versus los que se quedaron (No). Esto es fundamental para entender el desequilibrio de clases, si lo hay.
# Análisis univariado de características categóricas:
# Contar la frecuencia de cada categoría.
# Visualizar la distribución de cada categoría (por ejemplo, con gráficos de barras).
# Ver cómo cada categoría se relaciona con la variable Churn (por ejemplo, ¿los clientes con cierto tipo de contrato tienen más probabilidades de irse?).
# Análisis univariado de características numéricas:
# Obtener estadísticas descriptivas (media, mediana, desviación estándar, etc.).
# Visualizar la distribución (por ejemplo, con histogramas o boxplots).
# Ver cómo estas variables se relacionan con Churn (por ejemplo, ¿los clientes con facturas mensuales más altas o más bajas tienen más probabilidades de irse?).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# NOTA IMPORTANTE: Asumimos que el DataFrame 'df' ya está cargado y completamente
# transformado en tu entorno, tal como lo dejaste en el paso anterior.
# No se incluye la carga de datos ni las transformaciones de limpieza y tipos de datos aquí,
# ya que ya las realizaste exitosamente.

print("--- Análisis Exploratorio de Datos (EDA) ---")

# --- 1. Análisis de la variable objetivo: Churn ---
print("\n--- Distribución de la variable objetivo 'Churn' ---")
churn_counts = df['Churn'].value_counts()
print(churn_counts)
print(f"Porcentaje de Churn: {churn_counts['Yes'] / len(df) * 100:.2f}%")
print(f"Porcentaje de No-Churn: {churn_counts['No'] / len(df) * 100:.2f}%")

# Visualización de Churn
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='Churn', palette='viridis')
plt.title('Distribución de Clientes con Churn y Sin Churn')
plt.xlabel('Churn')
plt.ylabel('Número de Clientes')
plt.show()

# --- 2. Análisis de Características Categóricas seleccionadas vs. Churn ---

categorical_features_to_analyze = ['gender', 'Partner', 'Dependents', 'Contract']

for col in categorical_features_to_analyze:
    print(f"\n--- Análisis de la característica: '{col}' ---")

    # Frecuencia de cada categoría
    print(f"Frecuencia de categorías en '{col}':")
    print(df[col].value_counts())

    # Tasa de Churn por categoría
    churn_rate_by_category = df.groupby(col)['Churn'].value_counts(normalize=True).unstack()

    # Manejar el caso donde una categoría no tiene 'Yes' o 'No' para Churn
    if 'No' not in churn_rate_by_category.columns:
        churn_rate_by_category['No'] = 0
    if 'Yes' not in churn_rate_by_category.columns:
        churn_rate_by_category['Yes'] = 0

    churn_rate_by_category['Churn_Rate (%)'] = churn_rate_by_category['Yes'] * 100
    print(f"\nTasa de Churn por '{col}':")
    print(churn_rate_by_category[['Churn_Rate (%)']])

    # Visualización: Gráfico de barras de recuento con 'hue'
    plt.figure(figsize=(8, 5))
    sns.countplot(data=df, x=col, hue='Churn', palette='magma')
    plt.title(f'Distribución de Churn por {col}')
    plt.xlabel(col)
    plt.ylabel('Número de Clientes')
    plt.xticks(rotation=0)
    plt.legend(title='Churn')
    plt.show()
# Out:
# --- Análisis Exploratorio de Datos (EDA) ---
#
# --- Distribución de la variable objetivo 'Churn' ---
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64
# Porcentaje de Churn: 26.54%
# Porcentaje de No-Churn: 73.46%
# <ipython-input-43-f44b2051e190>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Churn', palette='viridis')
# --- Análisis de la característica: 'gender' ---
# Frecuencia de categorías en 'gender':
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
#
# Tasa de Churn por 'gender':
# Churn   Churn_Rate (%)
# gender
# Female       26.920872
# Male         26.160338
# <ipython-input-43-f44b2051e190>:39: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   churn_rate_by_category = df.groupby(col)['Churn'].value_counts(normalize=True).unstack()
# --- Análisis de la característica: 'Partner' ---
# Frecuencia de categorías en 'Partner':
# Partner
# No     3641
# Yes    3402
# Name: count, dtype: int64
#
# Tasa de Churn por 'Partner':
# Churn    Churn_Rate (%)
# Partner
# No            32.957979
# Yes           19.664903
# <ipython-input-43-f44b2051e190>:39: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   churn_rate_by_category = df.groupby(col)['Churn'].value_counts(normalize=True).unstack()
# --- Análisis de la característica: 'Dependents' ---
# Frecuencia de categorías en 'Dependents':
# Dependents
# No     4933
# Yes    2110
# Name: count, dtype: int64
#
# Tasa de Churn por 'Dependents':
# Churn       Churn_Rate (%)
# Dependents
# No               31.279140
# Yes              15.450237
# <ipython-input-43-f44b2051e190>:39: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   churn_rate_by_category = df.groupby(col)['Churn'].value_counts(normalize=True).unstack()
# --- Análisis de la característica: 'Contract' ---
# Frecuencia de categorías en 'Contract':
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64
#
# Tasa de Churn por 'Contract':
# Churn           Churn_Rate (%)
# Contract
# Month-to-month       42.709677
# One year             11.269518
# Two year              2.831858
# <ipython-input-43-f44b2051e190>:39: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   churn_rate_by_category = df.groupby(col)['Churn'].value_counts(normalize=True).unstack()

# %%
#Duplicados
print("Cantidad de filas duplicadas:", df.duplicated().sum())
# Out:
# Cantidad de filas duplicadas: 22

# %%
df.drop_duplicates(inplace=True)

# %%
#Duplicados
print("Cantidad de filas duplicadas:", df.duplicated().sum())
# Out:
# Cantidad de filas duplicadas: 0

# %%
#Normalización de categorías tipo ‘No internet service’
# --- Normalización de categorías tipo ‘No internet service’ o ‘No phone service’ ---

columns_replace_no_internet = [
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

columns_replace_no_phone = ['MultipleLines']

# Reemplazo de 'No internet service' por 'No'
for col in columns_replace_no_internet:
    if col in df.columns:
        df[col] = df[col].replace({'No internet service': 'No'})

# Reemplazo de 'No phone service' por 'No'
for col in columns_replace_no_phone:
    if col in df.columns:
        df[col] = df[col].replace({'No phone service': 'No'})

print("\nCategorías normalizadas: 'No internet service' y 'No phone service' reemplazadas por 'No'.")
# Out:
# Categorías normalizadas: 'No internet service' y 'No phone service' reemplazadas por 'No'.

# %%
# Reemplazo de 'No internet service' y 'No phone service' sin warnings
columns_replace_no_internet = [
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
    'TechSupport', 'StreamingTV', 'StreamingMovies'
]

columns_replace_no_phone = ['MultipleLines']

for col in columns_replace_no_internet:
    if col in df.columns:
        df[col] = df[col].astype('object').replace({'No internet service': 'No'})
        df[col] = df[col].astype('category')

for col in columns_replace_no_phone:
    if col in df.columns:
        df[col] = df[col].astype('object').replace({'No phone service': 'No'})
        df[col] = df[col].astype('category')

print("\nCategorías normalizadas sin warnings.")
# Out:
# Categorías normalizadas sin warnings.

# %%
# Verificar que ya no hay valores antiguos en esas columnas
for col in columns_replace_no_internet + columns_replace_no_phone:
    if col in df.columns:
        print(f"{col} - Categorías actuales: {df[col].cat.categories.tolist()}")
# Out:
# OnlineSecurity - Categorías actuales: ['No', 'Yes']
# OnlineBackup - Categorías actuales: ['No', 'Yes']
# DeviceProtection - Categorías actuales: ['No', 'Yes']
# TechSupport - Categorías actuales: ['No', 'Yes']
# StreamingTV - Categorías actuales: ['No', 'Yes']
# StreamingMovies - Categorías actuales: ['No', 'Yes']
# MultipleLines - Categorías actuales: ['No', 'Yes']

# %%
#Normalización de formatos (opcional)
df['Churn'] = df['Churn'].map({'Yes': True, 'No': False})

# %%
#Guardado intermedio del dataset limpio
df.to_csv("TelecomX_limpio.csv", index=False)

# %% [markdown]
# ## final ...

# %%
def limpiar_dataset_telecom(df_original):
    import pandas as pd
    import numpy as np

    # Copiamos el DataFrame original para no modificar el original
    df = df_original.copy()

    # --- Desanidar columnas ---
    # ... (el resto de la función limpiar_dataset_telecom)
    df_customer = df['customer'].apply(pd.Series)
    df_phone = df['phone'].apply(pd.Series)
    df_internet = df['internet'].apply(pd.Series)
    df_account = df['account'].apply(pd.Series)

    # Desanidar 'Charges' dentro de 'account' si existe
    if 'Charges' in df_account.columns:
        df_charges = df_account['Charges'].apply(pd.Series)
        df_account.drop(columns=['Charges'], inplace=True)
    else:
        df_charges = pd.DataFrame()

    # Eliminar columnas anidadas originales
    df.drop(columns=['customer', 'phone', 'internet', 'account'], inplace=True, errors='ignore')

    # Combinar todos los DataFrames desanidados
    dataframes_combinados = [df, df_customer, df_phone, df_internet, df_account, df_charges]
    df = pd.concat([d for d in dataframes_combinados if not d.empty], axis=1)

    # Eliminar columna customerID si existe
    df.drop(columns=['customerID'], inplace=True, errors='ignore')

    # Convertir 'Total' y 'Monthly' a numérico
    for col in ['Total', 'Monthly']:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

    # Limpieza de columna 'Churn'
    if 'Churn' in df.columns:
        df['Churn'] = df['Churn'].replace('', pd.NA)
        df.dropna(subset=['Churn'], inplace=True)

    # Columnas categóricas
    cat_cols = [
        'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
        'PaperlessBilling', 'PaymentMethod', 'Churn'
    ]
    for col in cat_cols:
        if col in df.columns:
            df[col] = df[col].astype('category')

    # Normalizar 'No internet service' y 'No phone service'
    columnas_no_internet = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
    columnas_no_phone = ['MultipleLines']

    for col in columnas_no_internet:
        if col in df.columns:
            df[col] = df[col].astype('object').replace({'No internet service': 'No'})
            df[col] = df[col].astype('category')

    for col in columnas_no_phone:
        if col in df.columns:
            df[col] = df[col].astype('object').replace({'No phone service': 'No'})
            df[col] = df[col].astype('category')


    return df

# %%
# Código agregado: Re-cargar los datos originales justo antes de usar la función
import pandas as pd
import requests
import numpy as np # Asegúrate de importar numpy si lo usa la función

# URL del archivo JSON crudo
url = 'https://raw.githubusercontent.com/TAGARA-TECH/ChallengeTelecomX/main/TelecomX_Data.json'

# Obtener los datos desde la "API" y crear el DataFrame original crudo
response = requests.get(url)
data_json = response.json()
df_original_raw = pd.DataFrame(data_json)

# Ahora, llama a la función de limpieza con el DataFrame original y crudo
df_limpio = limpiar_dataset_telecom(df_original_raw)

# Puedes añadir verificaciones o mostrar las primeras filas del DataFrame limpio
print("DataFrame limpio después de aplicar la función:")
print(df_limpio.head())
print("\nInformación del DataFrame limpio:")
df_limpio.info()
# Out:
# DataFrame limpio después de aplicar la función:
#   Churn  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    No  Female              0     Yes        Yes       9          Yes
# 1    No    Male              0      No         No       9          Yes
# 2   Yes    Male              0      No         No       4          Yes
# 3   Yes    Male              1     Yes         No      13          Yes
# 4   Yes  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL             No          Yes               No
# 1           Yes             DSL             No           No               No
# 2            No     Fiber optic             No           No              Yes
# 3            No     Fiber optic             No          Yes              Yes
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes         Yes              No        One year              Yes
# 1          No          No             Yes  Month-to-month               No
# 2          No          No              No  Month-to-month              Yes
# 3          No         Yes             Yes  Month-to-month              Yes
# 4         Yes         Yes              No  Month-to-month              Yes
#
#       PaymentMethod  Monthly    Total
# 0      Mailed check     65.6   593.30
# 1      Mailed check     59.9   542.40
# 2  Electronic check     73.9   280.85
# 3  Electronic check     98.0  1237.85
# 4      Mailed check     83.9   267.40
#
# Información del DataFrame limpio:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 0 to 7266
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Churn             7043 non-null   category
#  1   gender            7043 non-null   category
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   category
#  4   Dependents        7043 non-null   category
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   category
#  7   MultipleLines     7043 non-null   category
#  8   InternetService   7043 non-null   category
#  9   OnlineSecurity    7043 non-null   category
#  10  OnlineBackup      7043 non-null   category
#  11  DeviceProtection  7043 non-null   category
#  12  TechSupport       7043 non-null   category
#  13  StreamingTV       7043 non-null   category
#  14  StreamingMovies   7043 non-null   category
#  15  Contract          7043 non-null   category
#  16  PaperlessBilling  7043 non-null   category
#  17  PaymentMethod     7043 non-null   category
#  18  Monthly           7043 non-null   float64
#  19  Total             7043 non-null   float64
# dtypes: category(16), float64(2), int64(2)
# memory usage: 387.2 KB

# %%
def limpiar_dataset_telecom(df_original):
    import pandas as pd
    import numpy as np

    # Copiamos el DataFrame original para no modificar el original
    df = df_original.copy()

    # --- Desanidar columnas ---
    df_customer = df['customer'].apply(pd.Series)
    df_phone = df['phone'].apply(pd.Series)
    df_internet = df['internet'].apply(pd.Series)
    df_account = df['account'].apply(pd.Series)

    # Desanidar 'Charges' dentro de 'account' si existe
    if 'Charges' in df_account.columns:
        df_charges = df_account['Charges'].apply(pd.Series)
        df_account.drop(columns=['Charges'], inplace=True)
    else:
        df_charges = pd.DataFrame()

    # Eliminar columnas anidadas originales
    df.drop(columns=['customer', 'phone', 'internet', 'account'], inplace=True, errors='ignore')

    # Combinar todos los DataFrames desanidados
    dataframes_combinados = [df, df_customer, df_phone, df_internet, df_account, df_charges]
    df = pd.concat([d for d in dataframes_combinados if not d.empty], axis=1)

    # Eliminar columna customerID si existe
    df.drop(columns=['customerID'], inplace=True, errors='ignore')

    # Convertir 'Total' y 'Monthly' a numérico
    for col in ['Total', 'Monthly']:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

    # Limpieza de columna 'Churn'
    if 'Churn' in df.columns:
        df['Churn'] = df['Churn'].replace('', pd.NA)
        df.dropna(subset=['Churn'], inplace=True)

    # Columnas categóricas
    cat_cols = [
        'gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
        'PaperlessBilling', 'PaymentMethod', 'Churn'
    ]
    for col in cat_cols:
        if col in df.columns:
            df[col] = df[col].astype('category')

    # Normalizar 'No internet service' y 'No phone service'
    columnas_no_internet = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
    columnas_no_phone = ['MultipleLines']

    for col in columnas_no_internet:
        if col in df.columns:
            df[col] = df[col].astype('object').replace({'No internet service': 'No'})
            df[col] = df[col].astype('category')

    for col in columnas_no_phone:
        if col in df.columns:
            df[col] = df[col].astype('object').replace({'No phone service': 'No'})
            df[col] = df[col].astype('category')

    return df

# %%
df.head(5)
# Out:
#    Churn  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  False  Female              0     Yes        Yes       9          Yes
# 1  False    Male              0      No         No       9          Yes
# 2   True    Male              0      No         No       4          Yes
# 3   True    Male              1     Yes         No      13          Yes
# 4   True  Female              1     Yes         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0            No             DSL             No          Yes               No
# 1           Yes             DSL             No           No               No
# 2            No     Fiber optic             No           No              Yes
# 3            No     Fiber optic             No          Yes              Yes
# 4            No     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes         Yes              No        One year              Yes
# 1          No          No             Yes  Month-to-month               No
# 2          No          No              No  Month-to-month              Yes
# 3          No         Yes             Yes  Month-to-month              Yes
# 4         Yes         Yes              No  Month-to-month              Yes
#
#       PaymentMethod  Monthly    Total
# 0      Mailed check     65.6   593.30
# 1      Mailed check     59.9   542.40
# 2  Electronic check     73.9   280.85
# 3  Electronic check     98.0  1237.85
# 4      Mailed check     83.9   267.40

# %%
df_original_raw.head(5)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# NOTA IMPORTANTE: Asumimos que el DataFrame 'df' ya está cargado y completamente
# transformado en tu entorno, tal como lo dejaste en el paso anterior.
# No se incluye la carga de datos ni las transformaciones de limpieza y tipos de datos aquí,
# ya que ya las realizaste exitosamente.

print("--- Análisis Exploratorio de Datos (EDA) ---")

# --- 1. Análisis de la variable objetivo: Churn ---
print("\n--- Distribución de la variable objetivo 'Churn' ---")
churn_counts = df['Churn'].value_counts()
print(churn_counts)

# Acceder a los conteos usando los índices booleanos True y False
# Verificar si True y False existen en el índice antes de acceder
churn_yes_count = churn_counts.get(True, 0) # Usar .get() con un valor predeterminado de 0
churn_no_count = churn_counts.get(False, 0)

if len(df) > 0: # Evitar la división por cero si el DataFrame está vacío
    print(f"Porcentaje de Churn: {churn_yes_count / len(df) * 100:.2f}%")
    print(f"Porcentaje de No-Churn: {churn_no_count / len(df) * 100:.2f}%")
else:
    print("DataFrame vacío, no se puede calcular porcentajes de Churn.")


# Visualización de Churn
plt.figure(figsize=(6, 4))
# Asegurarse de que la columna 'Churn' sea tratada correctamente por seaborn.
# Como ahora es booleana, seaborn debería manejarla, pero establecer el orden explícitamente puede ayudar.
sns.countplot(data=df, x='Churn', palette='viridis', order=[False, True]) # Especificar el orden como False, True
plt.title('Distribución de Clientes con Churn y Sin Churn')
plt.xlabel('Churn (False: No, True: Yes)') # Actualizar la etiqueta para reflejar los valores booleanos
plt.ylabel('Número de Clientes')
plt.xticks([0, 1], ['No', 'Yes']) # Establecer las etiquetas de los ticks como 'No' y 'Yes' para mayor claridad
plt.show()

# --- 2. Análisis de Características Categóricas seleccionadas vs. Churn ---

categorical_features_to_analyze = ['gender', 'Partner', 'Dependents', 'Contract']

for col in categorical_features_to_analyze:
    print(f"\n--- Análisis de la característica: '{col}' ---")

    # Frecuencia de cada categoría
    print(f"Frecuencia de categorías en '{col}':")
    print(df[col].value_counts())

    # Tasa de Churn por categoría
    # Como Churn es booleano, al hacer unstack las columnas serán True y False
    churn_rate_by_category = df.groupby(col)['Churn'].value_counts(normalize=True).unstack()

    # Manejar el caso donde una categoría no tiene 'True' o 'False' para Churn
    if True not in churn_rate_by_category.columns:
        churn_rate_by_category[True] = 0
    if False not in churn_rate_by_category.columns:
        churn_rate_by_category[False] = 0

    # Calcular la Tasa de Churn usando la columna True
    churn_rate_by_category['Churn_Rate (%)'] = churn_rate_by_category[True] * 100
    print(f"\nTasa de Churn por '{col}':")
    # Mostrar la columna de Tasa de Churn
    print(churn_rate_by_category[['Churn_Rate (%)']])

    # Visualización: Gráfico de barras de recuento con 'hue'
    plt.figure(figsize=(8, 5))
    # Hue utilizará los valores booleanos (True/False). Especificar hue_order para claridad en la leyenda.
    sns.countplot(data=df, x=col, hue='Churn', palette='magma', hue_order=[False, True])
    plt.title(f'Distribución de Churn por {col}')
    plt.xlabel(col)
    plt.ylabel('Número de Clientes')
    plt.xticks(rotation=0)
    # Actualizar las etiquetas de la leyenda a 'No' y 'Yes'
    plt.legend(title='Churn', labels=['No', 'Yes'])
    plt.show()
# Out:
# --- Análisis Exploratorio de Datos (EDA) ---
#
# --- Distribución de la variable objetivo 'Churn' ---
# Churn
# False    5164
# True     1857
# Name: count, dtype: int64
# Porcentaje de Churn: 26.45%
# Porcentaje de No-Churn: 73.55%
# <ipython-input-68-c65e819092cb>:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Churn', palette='viridis', order=[False, True]) # Especificar el orden como False, True
# --- Análisis de la característica: 'gender' ---
# Frecuencia de categorías en 'gender':
# gender
# Male      3541
# Female    3480
# Name: count, dtype: int64
#
# Tasa de Churn por 'gender':
# Churn   Churn_Rate (%)
# gender
# Female       26.839080
# Male         26.066083
# <ipython-input-68-c65e819092cb>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   churn_rate_by_category = df.groupby(col)['Churn'].value_counts(normalize=True).unstack()
# --- Análisis de la característica: 'Partner' ---
# Frecuencia de categorías en 'Partner':
# Partner
# No     3619
# Yes    3402
# Name: count, dtype: int64
#
# Tasa de Churn por 'Partner':
# Churn    Churn_Rate (%)
# Partner
# No            32.826748
# Yes           19.664903
# <ipython-input-68-c65e819092cb>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   churn_rate_by_category = df.groupby(col)['Churn'].value_counts(normalize=True).unstack()
# --- Análisis de la característica: 'Dependents' ---
# Frecuencia de categorías en 'Dependents':
# Dependents
# No     4911
# Yes    2110
# Name: count, dtype: int64
#
# Tasa de Churn por 'Dependents':
# Churn       Churn_Rate (%)
# Dependents
# No               31.174913
# Yes              15.450237
# <ipython-input-68-c65e819092cb>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   churn_rate_by_category = df.groupby(col)['Churn'].value_counts(normalize=True).unstack()
# --- Análisis de la característica: 'Contract' ---
# Frecuencia de categorías en 'Contract':
# Contract
# Month-to-month    3853
# Two year          1695
# One year          1473
# Name: count, dtype: int64
#
# Tasa de Churn por 'Contract':
# Churn           Churn_Rate (%)
# Contract
# Month-to-month       42.642097
# One year             11.269518
# Two year              2.831858
# <ipython-input-68-c65e819092cb>:53: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   churn_rate_by_category = df.groupby(col)['Churn'].value_counts(normalize=True).unstack()

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ## Informe Final Preliminar: Desafío de Churn en Telecom X
# 1. Introducción al Desafío
# Hemos sido contratados como analistas de datos por Telecom X para abordar un problema crítico: el alto índice de evasión de clientes (churn). El objetivo principal de este proyecto es identificar las posibles causas de esta evasión a través del análisis de datos. Como primer paso, se nos ha proporcionado un conjunto de datos que requiere un proceso de ETL (Extracción, Transformación y Carga) y un Análisis Exploratorio de Datos (EDA).
#
# 2. Estado Actual del Procesamiento de Datos (ETL)
# La fase de Extracción se ha completado con éxito. Se ha accedido a los datos del cliente desde la "API" (un archivo JSON alojado en GitHub) utilizando la librería requests de Python, y se ha cargado correctamente en un DataFrame de Pandas.
#
# El DataFrame inicial tiene las siguientes dimensiones: 7267 filas y 6 columnas. Las columnas son: customerID, Churn, customer, phone, internet, y account.
#
# 3. Hallazgos Preliminares y Estructura de Datos
# Un análisis inicial del DataFrame ha revelado una estructura particular en los datos:
#
# Las columnas customer, phone, internet y account son de tipo object, lo que indica que contienen estructuras de datos anidadas, específicamente diccionarios. Estas columnas encapsulan información valiosa sobre las características del cliente, sus servicios telefónicos, servicios de internet y detalles de la cuenta.
#
# La columna Churn, que es nuestra variable objetivo (indica si un cliente se fue o no), presenta tres valores únicos: 'No', 'Yes', y una cadena vacía (''). La presencia de cadenas vacías en esta columna es un problema de calidad de datos que debe ser abordado antes de cualquier análisis predictivo.
#
# 4. Próximos Pasos en el Proceso de ETL y Análisis
# Para avanzar en el desafío y preparar los datos para un análisis más profundo, los siguientes pasos son cruciales:
#
# Aplanamiento de Columnas Anidadas: La tarea más inmediata es desanidar las columnas customer, phone, internet y account. Cada clave dentro de estos diccionarios anidados debe convertirse en una columna separada en el DataFrame principal. Esto es fundamental para hacer que la información sea accesible y utilizable para el análisis.
#
# Tratamiento de Valores Faltantes/Inválidos en Churn: Se debe decidir cómo manejar las filas donde la columna Churn contiene una cadena vacía. Las opciones incluyen la eliminación de estas filas si su cantidad es insignificante o la imputación si es apropiado, aunque para una variable objetivo binaria, la eliminación suele ser la opción más segura si los datos son realmente ausentes.
#
# Conversión de Tipos de Datos: Después de aplanar las columnas, será necesario revisar y convertir los tipos de datos de las nuevas columnas. Por ejemplo, SeniorCitizen, tenure, MonthlyCharges y TotalCharges deberían ser numéricos. Otras columnas, como gender, Partner, InternetService, etc., deberían convertirse a tipos categóricos para optimizar la memoria y facilitar el análisis.
#
# Análisis Exploratorio de Datos (EDA): Una vez que los datos estén limpios y estructurados correctamente, se procederá con un EDA exhaustivo. Esto incluirá:
#
# Análisis de la distribución de las variables.
# Identificación de correlaciones entre las características y la variable Churn.
# Visualizaciones para entender qué factores parecen influir más en la decisión de un cliente de darse de baja.
# 5. Conclusiones Preliminares
# Hasta ahora, la extracción de datos se ha realizado correctamente, sentando las bases para el resto del proyecto. Sin embargo, la estructura anidada de los datos y la presencia de valores inválidos en la columna Churn son los principales obstáculos que deben superarse en la fase de transformación para permitir un análisis significativo.
